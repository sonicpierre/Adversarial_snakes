# %%
import snake_pygame
import torch

# %%
from snake_pygame import agent
agent.train()
# Out:
# /notebooks/snake_pygame/model.py:36: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /opt/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:207.)
#   state = torch.tensor(state, dtype=torch.float)
# Game 1 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 2 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 3 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 4 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 5 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 6 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 7 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 8 Score 0 Record: 0
# Score : 0
# Mean score : 0.0
# Game 9 Score 1 Record: 1
# Score : 1
# Mean score : 0.1111111111111111
# Game 10 Score 0 Record: 1
# Score : 0
# Mean score : 0.1
# Game 11 Score 1 Record: 1
# ...

# %%
# !tar -zcvf model.tar.gz model/
# Out:
# model/
# model/model 78.pth
# model/model 65.pth
# model/model 68.pth
# model/model 34.pth
# model/model 84.pth
# model/model 83.pth
# model/model 14.pth
# model/model 129.pth
# model/model 9.pth
# model/model 57.pth
